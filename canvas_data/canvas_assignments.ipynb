# %%
import pandas as pd

pd.set_option("display.max_columns", None)
pd.set_option("display.max_rows", None)
pd.set_option("display.max_colwidth", None)

assignments_df = pd.read_csv('Canvas Assignments-Grid view.csv')
assignments_df.head()
# Out:
#         Assignment Id Canvas Course Code  \
# 0  168550000000008551     LLP_PT_2010_CS
# 1  168550000000008552     LLP_PT_2010_CS
# 2  168550000000008553     LLP_PT_2010_CS
# 3  168550000000008554     LLP_PT_2010_CS
# 4  168550000000009216     LLP_FT_2010_CS
#
#                                 Assignment Title  \
# 0  Behavioral Mock Interview Practice Reflection
# 1  Behavioral Mock Interview Practice Reflection
# 2  Behavioral Mock Interview Practice Reflection
# 3  Behavioral Mock Interview Practice Reflection
# 4  Behavioral Mock Interview Practice Reflection
#
#                                                       Assignment Url  \
# 0  https://lambdaschool.instructure.com/courses/497/assignments/8551
# 1  https://lambdaschool.instructure.com/courses/497/assignments/8552
# 2  https://lambdaschool.instructure.com/courses/497/assignments/8553
# 3  https://lambdaschool.instructure.com/courses/497/assignments/8554
# ...

# %%
assignments_df.describe(include='all')
# Out:
#         Assignment Id Canvas Course Code       Assignment Title  \
# count    7.170000e+02                717                    717
# unique            NaN                 33                    109
# top               NaN        LLP_FT_2010  Mock Interview Guides
# freq              NaN                 59                     45
# mean     1.685500e+17                NaN                    NaN
# std      1.077141e+03                NaN                    NaN
# min      1.685500e+17                NaN                    NaN
# 25%      1.685500e+17                NaN                    NaN
# 50%      1.685500e+17                NaN                    NaN
# 75%      1.685500e+17                NaN                    NaN
# max      1.685500e+17                NaN                    NaN
#
#                                                             Assignment Url  \
# count                                                                  717
# ...

# %%
len(assignments_df['Assignment Title'].value_counts())
# Out:
# 109

# %%
peers_df = assignments_df[assignments_df['Assignment Title'].str.contains("Peer")]

# %%
peers_df
# Out:
# 3 18:21
# 504                   llp                         NaN  2020-12-05 01:35
# 505                   llp                         NaN  2020-12-03 18:21
# 506                   llp                         NaN  2020-12-03 18:21
# 507                   llp                         NaN  2020-12-03 18:21
# 508                   llp                         NaN  2020-12-03 18:21
# 509                   llp                         NaN  2020-12-03 18:21
# 510                   llp                         NaN  2020-12-03 18:21
# 511                   llp                         NaN  2020-12-03 18:21
# 512                   llp                         NaN  2020-12-03 18:21
# 513                   llp                         NaN  2020-12-03 18:21
# 514                   llp                         NaN  2020-12-03 18:21
# 515                   llp                         NaN  2020-12-03 18:21
# 516                   llp                         NaN  2020-12-03 18:21
# ...
